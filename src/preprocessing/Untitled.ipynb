# %%
import os
a = '../'
for abs_file_dir, _, filenames in os.walk(a):
        for filename in filenames:
                rel_file_dir = os.path.relpath(abs_file_dir, start=a)
                print(abs_file_dir)
                print(rel_file_dir)
                print(filename)
                print('----')
# Out:
# ../
# .
# dataset_development.ipynb
# ----
# ../
# .
# train.py
# ----
# ../
# .
# config.ini
# ----
# ../
# .
# discotubedataset.py
# ----
# ../
# .
# dataloader.py
# ----
# ../
# .
# metrics.py
# ----
# ../.ipynb_checkpoints
# .ipynb_checkpoints
# dataset_development-checkpoint.ipynb
# ----
# ../.ipynb_checkpoints
# .ipynb_checkpoints
# train-checkpoint.py
# ----
# ../.ipynb_checkpoints
# .ipynb_checkpoints
# config-checkpoint.ini
# ----
# ../.ipynb_checkpoints
# .ipynb_checkpoints
# discotubedataset-checkpoint.py
# ----
# ../.ipynb_checkpoints
# .ipynb_checkpoints
# dataloader-checkpoint.py
# ----
# ../.ipynb_checkpoints
# .ipynb_checkpoints
# metrics-checkpoint.py
# ----
# ../__pycache__
# __pycache__
# dataset.cpython-37.pyc
# ----
# ../__pycache__
# __pycache__
# convnet.cpython-37.pyc
# ----
# ../__pycache__
# __pycache__
# data_loader.cpython-37.pyc
# ----
# ../__pycache__
# __pycache__
# dataloader.cpython-37.pyc
# ----
# ../__pycache__
# __pycache__
# ...
